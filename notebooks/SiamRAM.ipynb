# %%
import json
import os
import sys
from collections import defaultdict

import numpy as np
import pandas as pd

sys.path.append("..")
from models.SiamABC.tracker.tracker_setup import get_tracker
from models.SiamRAM import SiamRAMTracker
from vis.test_model import run_inference

with open("/home/moha/AIC-4/data_competition/metadata/contestant_manifest.json", "r") as f:
    manifest = json.load(f)
test_public_lb = manifest["public_lb"]
manifest.keys()
# Out:
# dict_keys(['train', 'public_lb'])

# %%
video_paths = [
    # "/home/moha/AIC-4/data_competition/dataset2/Gull2/Gull2_24.mp4",
    # "/home/moha/AIC-4/data_competition/dataset3/car16_3/car16_3_24.mp4",
    # "/home/moha/AIC-4/data_competition/dataset2/RaceCar1/RaceCar1_24.mp4",
    # "/home/moha/AIC-4/data_competition/dataset5/uav2/uav2_30.mp4",
    # "/home/moha/AIC-4/data_competition/dataset5/uav7/uav7_30.mp4",
    # "/home/moha/AIC-4/data_competition/dataset2/RcCar6/RcCar6_24.mp4",
    # "/home/moha/AIC-4/data_competition/dataset2/Motor1/Motor1_24.mp4",
    # "/home/moha/AIC-4/data_competition/dataset2/MountainBike5/MountainBike5_30.mp4",
    # "/home/moha/AIC-4/data_competition/dataset1/person_3/person_3.mp4",
    # "/home/moha/AIC-4/data_competition/dataset3/truck/truck_30.mp4",
    # "/home/moha/AIC-4/data_competition/dataset3/human3/human3_24.mp4",
    # "/home/moha/AIC-4/data_competition/dataset1/sheeps_2/sheeps_2.mp4",
    # "/home/moha/AIC-4/data_competition/dataset2/Animal3/Animal3_30.mp4",
    # "/home/moha/AIC-4/data_competition/dataset5/person16/person16_96.mp4",
    # "/home/moha/AIC-4/data_competition/dataset3/electric_box/electric_box_24.mp4",
    # "/home/moha/AIC-4/data_competition/dataset2/RcCar4/RcCar4_24.mp4",
    "/home/moha/AIC-4/data_competition/dataset4/group2/group2_96.mp4",
    "/home/moha/AIC-4/data_competition/dataset3/jogging2/jogging2_30.mp4",
    "/home/moha/AIC-4/data_competition/dataset3/car6_2/car6_2_30.mp4",
    "/home/moha/AIC-4/data_competition/dataset4/person19/person19_96.mp4",
    "/home/moha/AIC-4/data_competition/dataset3/couple/couple_24.mp4",
    "/home/moha/AIC-4/data_competition/dataset3/tennis_player1_2/tennis_player1_2_30.mp4",
    "/home/moha/AIC-4/data_competition/dataset5/car4/car4_96.mp4"
]

# %%
from omegaconf import OmegaConf

weights_path = "/home/moha/AIC-for submission/SiamRAM/checkpoints/head_epoch_000.pth"
yaml_config_path = "/home/moha/AIC-for submission/SiamRAM/config/inference_config.yaml" 

config = OmegaConf.load(yaml_config_path)

# wrapped = get_trt_tracker(
#     config=config,
#     weights_path=weights_path,
#     **config.trt_engine  
# )


wrapped = get_tracker(
    config=config,
    weights_path=weights_path,
)


tracker = SiamRAMTracker(
    siam_tracker=wrapped,
    **config.ram_tracker 
)


start = 1
for i in range(start, start + len(video_paths)):
    video_path = video_paths[i - start]
    ann_path = os.path.join(os.path.dirname(video_path), "annotation.txt")
    output_path = f"../outputs/test_5_after/test_{i}.mp4"

    # Load initial bbox
    init_bbox = np.loadtxt(ann_path, delimiter=",", dtype=np.float32).tolist()
    if not isinstance(init_bbox[0], (int, float)):
        init_bbox = init_bbox[0]
        
    print(f"Processing Video {i}: {video_path}")

    run_inference(
        video_path=video_path,
        initial_bbox=init_bbox,
        tracker=tracker,
        output_path=output_path
    )
# Out:
# WARNING:torch_tensorrt.dynamo.conversion.aten_ops_converters:Unable to import quantization op. Please install modelopt library (https://github.com/NVIDIA/TensorRT-Model-Optimizer?tab=readme-ov-file#installation) to add support for compiling quantized models
# WARNING:py.warnings:/home/moha/miniconda3/envs/SiamABC_modern/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
#
# WARNING:py.warnings:/home/moha/miniconda3/envs/SiamABC_modern/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# {'penalty_k': 0.062, 'window_influence': 0.38, 'lr': 0.4, 'windowing': 'cosine', 'total_stride': 16, 'score_size': 16, 'N': 10, 'dynamic_update': True, 'similarity_score': False, 'stride': 2, 'smooth': False, 'bbox_ratio': 0.5, 'template_bbox_offset': 0.2, 'search_context': 2, 'instance_size': 256, 'template_size': 128, 'memory_window_size': 20, 'dynamic_update_threshold': 0.87, 'running_confidence_floor_value': 60, 'iou_threshold': 0.6, 'warmup_frames': 35, 'warmup_window_size': 8}
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Processing Video 1: /home/moha/AIC-4/data_competition/dataset4/group2/group2_96.mp4
# Loading yolo11n.engine for TensorRT inference...
# [04/30/2026-03:06:23] [TRT] [I] Loaded engine size: 6 MiB
# [04/30/2026-03:06:23] [TRT] [I] [MemUsageChange] TensorRT-managed allocation in IExecutionContext creation: CPU +0, GPU +4, now: CPU 0, GPU 9 (MiB)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 43
#      39     init_bbox = init_bbox[0]
#      41 print(f"Processing Video {i}: {video_path}")
# ---> 43 run_inference(
#      44     video_path=video_path,
#      45     initial_bbox=init_bbox,
#      46     tracker=tracker,
#      47     output_path=output_path
#      48 )
#
# File ~/AIC-for submission/SiamRAM/vis/test_model.py:342, in run_inference(initial_bbox, video_path, tracker, output_path, output_video)
#     339     break
#     341 t0 = time.perf_counter()
# --> 342 result = tracker.update(frame)
#     343 elapsed_ms = (time.perf_counter() - t0) * 1000.0
#     344 frame_times.append(elapsed_ms)
#
# File ~/AIC-for submission/SiamRAM/models/SiamRAM.py:468, in SiamRAMTracker.update(self, frame)
#     466     bbox, score = self._occlusion_update(proc_frame)
#     467 else:
# --> 468     bbox, score = self._normal_update(proc_frame)
#     470 self.prev_gray = current_gray
#     472 # ── Scale outputs back to full-frame coordinates ─────────────────────────
#
# File ~/AIC-for submission/SiamRAM/models/SiamRAM.py:520, in SiamRAMTracker._normal_update(self, frame)
#     490 def _normal_update(self, frame: np.ndarray) -> Tuple[np.ndarray, float]:
#     491     """
#     492     Inputs:
#     493         frame - current video frame as a numpy BGR array
#    (...)
#     518         correct EKF state. If this bookkeeping is wrong, recovery will fail.
#     519     """
# --> 520     pred_bbox, score, _ = self.tracker.update(frame)
#     521     pred_bbox = np.array(pred_bbox, dtype=int)
#     523     if (self._yolo_filter_class
#     524         and not self._class_warmup_done
#     525         and self.frame_idx <= self._yolo_class_detect_frames * 3
#     526         and self.frame_idx % max(1, self._yolo_class_detect_frames) == 0):
#
# File ~/AIC-for submission/SiamRAM/models/SiamABC/tracker/SiamABC_Tracker.py:200, in SiamABCTracker.update(self, search, *kw)
#     199 def update(self, search: NDArray, *kw):
# --> 200     pred_bbox, pred_score, sim_score, search_crop_raw, search_bbox_in_crop, search_features = self.run_track(search)
#     202     self.tracking_state.bbox = pred_bbox
#     203     self.tracking_state.pred_score = pred_score
#
# File ~/AIC-for submission/SiamRAM/models/SiamABC/tracker/SiamABC_Tracker.py:263, in SiamABCTracker.run_track(self, search)
#     261 self.tracking_state.mapping = search_context
#     262 self.tracking_state.prev_size = search_bbox_in_crop[2:]
# --> 263 pred_bbox, pred_score, sim_score, _ = self.track(
#     264     search_features, self.dynamic_search_features, self.dynamic_template_features
#     265 )
#     266 pred_bbox = self._rescale_bbox(pred_bbox, self.tracking_state.mapping)
#     267 pred_bbox = clamp_bbox(pred_bbox, search.shape)
#
# File ~/miniconda3/envs/SiamABC_modern/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/AIC-for submission/SiamRAM/models/SiamABC/tracker/SiamABC_Tracker.py:272, in SiamABCTracker.track(self, search_features, dynamic_search_features, dynamic_template_features)
#     270 @torch.no_grad()
#     271 def track(self, search_features, dynamic_search_features, dynamic_template_features):
# --> 272     track_result = self.net.track(
#     273         search_features=search_features,
#     274         dynamic_search_features=dynamic_search_features,
#     275         template_features=self._template_features,
#     276         dynamic_template_features=dynamic_template_features,
#     277         lam=self._tta_lam,
#     278     )
#     279     return self._postprocess(track_result=track_result)
#
# File ~/AIC-for submission/SiamRAM/models/SiamABC/model/SiamABC.py:164, in SiamABCNet.track(self, search_features, dynamic_search_features, template_features, dynamic_template_features, lam)
#     161 search_attention = self.polarized_self_attention(search_combined_features)
#     162 search_mixed_attention = self.attention_neck(search_attention)
# --> 164 bbox_pred, cls_pred = self.connector(template_mixed_attention=template_mixed_attention,
#     165                                      search_mixed_attention=search_mixed_attention,
#     166                                      search=search_features, lam=lam)
#     167 return {
#     168     constants.TARGET_REGRESSION_LABEL_KEY: bbox_pred,
#     169     constants.TARGET_CLASSIFICATION_KEY: cls_pred,
#     170     constants.TRACKER_TARGET_SEARCH_SIM_SCORE: None,
#     171     constants.TRACKER_ATTENTION_MAP: search_mixed_attention
#     172 }
#
# File ~/AIC-for submission/SiamRAM/models/SiamABC/model/SiamABC.py:105, in SiamABCNet.connector(self, template_mixed_attention, search_mixed_attention, search, lam)
#     103 def connector(self, template_mixed_attention: torch.Tensor, search_mixed_attention: torch.Tensor,
#     104               search: torch.Tensor, lam: torch.Tensor) -> Tuple[str, torch.Tensor]:
# --> 105     bbox_pred, cls_pred, _, _ = self.connect_model(search_org=search, search=search_mixed_attention,
#     106                                                    kernel=template_mixed_attention, lam=lam)
#     107     return bbox_pred, cls_pred
#
# File ~/miniconda3/envs/SiamABC_modern/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/SiamABC_modern/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/AIC-for submission/SiamRAM/models/SiamABC/model/blocks.py:289, in BoxTower.forward(self, search_org, search, kernel, lam)
#     286 x = torch.exp(x)
#     288 # cls tower
# --> 289 c = self.cls_tower(cls_dw, lam)
#     290 cls = 0.1 * self.cls_pred(c)
#     292 return x, cls, cls_dw, x_reg
#
# File ~/miniconda3/envs/SiamABC_modern/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/SiamABC_modern/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/AIC-for submission/SiamRAM/models/SiamABC/model/blocks.py:44, in AdaptiveSequential.forward(self, x, lam)
#      42         x = module(x, lam)
#      43     else:
# ---> 44         x = module(x)
#      45 return x
#
# File ~/miniconda3/envs/SiamABC_modern/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/SiamABC_modern/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/AIC-for submission/SiamRAM/models/SiamABC/model/blocks.py:201, in ConvBlock.forward(self, x)
#     199 def forward(self, x: torch.Tensor) -> torch.Tensor:
#     200     x = self.depthwise(x)
# --> 201     x = self.pointwise(x)
#     202     return x
#
# File ~/miniconda3/envs/SiamABC_modern/lib/python3.10/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/SiamABC_modern/lib/python3.10/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/miniconda3/envs/SiamABC_modern/lib/python3.10/site-packages/torch/nn/modules/conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/miniconda3/envs/SiamABC_modern/lib/python3.10/site-packages/torch/nn/modules/conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
# dunamic_search = 4.3760
# search = 4.3760   
# dynamic_template = 1.0940
# template = 1.0940
# attention = 0.3865

# s = 0
# range_ = 200
# for i in range(range_):
#     if i==0:
#         s+=template + dynamic_template + dunamic_search + search + attention*2
#     elif i%10==0:
#         s+=dynamic_template + dunamic_search + search + attention*2
#     else:
#         s+=search + attention

# s/range_

# %%
9.5115/3
# Out:
# 3.1705

# %%
config.trt_engine
# Out:
# {'lambda_tta': 0.1, 'fp16': False, 'cuda_id': 0}

# %%
# 0.768 score on public lb
test_public_lb = manifest["public_lb"]
with open("/home/moha/AIC-4/data_competition/metadata/contestant_manifest.json", "r") as f:
    manifest = json.load(f)
manifest.keys()
test_public_lb = manifest["public_lb"]

# test_pub_2 = {k:v for k , v in manifest["public_lb"].items() if v["dataset"]=="dataset2"}


folder_names = [
    # "uav2",
    # "uav7",
    # "RcCar6",
    "Motor1",
    "MountainBike5",
    "person_3",
    "truck",
    "human3",
    "sheeps_2",
    "Animal3",
    "person16",
    "electric_box",
    "RcCar4",
    "group2",
    "truck",
    "jogging2",
    "car6_2",
    "person19",
    "couple",
    "tennis_player1_2",
    "car4",
]

data_dir = "../../AIC-4/data_competition"
outputs_dir = "outputs/SiamDAM__test"
test_public_lb = {
k: v for k, v in manifest["public_lb"].items()
if v["dataset"] in [
    "dataset1",
    "dataset2",
    "dataset3",
    "dataset4",
    "dataset5"
]
# and v["seq_name"] in  folder_names
}
model_size = "M"
weights_path = "/home/moha/AIC-for submission/SiamRAM/checkpoints/head_epoch_000.pth"
# weights_path = "/home/moha/AIC-4/checkpoints/bbox_head/all_datasets_finetuning/part_2/head_epoch_001.pth"
config_path = "../../AIC-4/external/SiamABC/core/config"
config_name = "SiamABC_tracker"

# config = load_hydra_config_from_path(config_path=config_path, config_name=config_name)
# config["model"]["model_size"] = 'S' if model_size=="S_Tiny" else 'M'
# config["tracker"]["N"] =10
# config["tracker"]["lr"] = 0.4
# config["tracker"]["dynamic_update"] = True 
# config["tracker"]["memory_window_size"] = 20
# config["tracker"]["dynamic_update_threshold"] = 0.87
# config["tracker"]["running_confidence_floor_value"] = 100
# config["tracker"]["search_context"] = 2
# config["tracker"]["iou_threshold"] = 0.6
# config["model"]["_target_"] = "models.SiamABC.model.SiamABC.SiamABCNet"
# config["tracker"]["_target_"] = "models.SiamABC.tracker.SiamABC_Tracker.SiamABCTracker"
# config["tracker"]["warmup_frames"] = 35
# config["tracker"]["warmup_window_size"] = 8

# config["tracker"]["jump_center_shift"] = 0.7
# config["tracker"]["jump_size_ratio"] = 4
# config["tracker"]["jump_score_override"] = 0.99



# config["tracker"]["window_influence"] =  0.45 
# config["tracker"]["penalty_k"] = 0.10


# wrapped = get_tracker(config=config, weights_path=weights_path , lambda_tta=0.1 , continuous=False)



wrapped = get_trt_tracker(
    config=config,
    weights_path=weights_path,
    **config.trt_engine  
)


# siam.all_memory_imgs = deque(maxlen=250)   # was 5000
# siam.classification_scores = deque(maxlen=250)


tracker = SiamRAMTracker(
        siam_tracker        = wrapped,
        yolo_weights        = "yolo11n.pt",

        # ── Core thresholds ───────────────────────────────────────────────────
        conf_threshold      = 0.55,      # score BELOW this starts the entry streak
        reacq_threshold     = 0.7,      # tracker score to exit occlusion (phase 0)
        occ_siam_reacq_threshold = 0.80,
        yolo_conf           = 0.3,
        app_match_threshold = 0.1,      # cosine sim to accept tracker bbox as target
        occ_siam_margin=0.5,
        nudge_alpha         = 0.0,

        # ── NEW: Occlusion entry hysteresis ───────────────────────────────────
        entry_patience      = 1,        # N consecutive bad frames before occlusion

        # ── NEW: Multi-frame candidate collection ─────────────────────────────
        cand_collection_frames = 1,     # YOLO collection frames before final DRM

        # ── NEW: Velocity scoring weight & guard ──────────────────────────────
        drm_lam_cand_vel    = 0.0,     # weight of vel_score in final DRM phase
                                        # set 0 to disable velocity scoring
        vel_score_min_speed = 0.5,      # min EKF speed (px/frame) to use vel score
                                        # if EKF speed < this → vel_score = 0.5 (neutral)

        # ── NEW: Tiny / long-distance object ROI parameters ───────────────────
        # Used automatically when _is_long_distance() returns True.
        long_distance_area_fraction =  0.030,
        tiny_roi_start_expand            = 8.0,
        tiny_yolo_search_expand          = 20.0,
        tiny_search_expand_growth_factor = 1.3,
        tiny_search_expand_growth_every  = 50,
        tiny_search_expand_max           = 40.0,

        # ── DRM (existing params) ─────────────────────────────────────────────
        drm_tau_sim         = 0.6,
        mem_capacity        = 50,
        drm_mmin            = 3,
        drm_capacity        = 20,
        history_decay       = 0.1,
        drm_lam_dist        = 0.0,
        drm_lam_cand_dir    = 0.0,
        drm_lam_time        = 0.0,
        drm_lam_app         = 1,
        drm_lam_iou         = 0.0,
        drm_lam_mot         = 0.0,
        drm_margin          = 0.6,
        drm_skip_threshold  = 23,
        drm_top_k           = 100,
        vel_dir_hard_gate = 0.4,   # |cos| threshold below which score → 0.05
        yolo_filter_class  = False, # filter candidates to target class
        yolo_class_detect_frames   = 5,     # stride 

        # ── History ───────────────────────────────────────────────────────────
        conf_history_len    = 200,
        size_history_len    = 200,
        history_skip_last   = 8,

        # ── ROI expansion (normal objects) ────────────────────────────────────
        roi_start_expand                 = 20,
        yolo_search_expand               = 100,
        search_expand_growth_factor      = 1.4,
        search_expand_growth_every       = 150,
        search_expand_max                = 500.0,

        # ── Misc ──────────────────────────────────────────────────────────────
        velocity_window_average          = 200,
        shrinkage_max_lookback           = 30,
        enter_occlusion_on_loss          = True,
        drm_gamma                        = 0,
        debug=False

    )
for i, (key, value) in enumerate(test_public_lb.items()):

    print(f"Processing video {i + 1}/{len(test_public_lb)}: {value['video_path']}")
    video_path = os.path.join(
        data_dir, value["video_path"]
    )
    ann_path = os.path.join(
        data_dir, value["annotation_path"]
    )

    output_path = os.path.join(
        outputs_dir, value["video_path"]
    )

    init_bbox = np.loadtxt(ann_path, delimiter=",", dtype=np.float32).tolist()

    run_inference(
        video_path=video_path,
        initial_bbox=init_bbox,
        tracker=tracker,
        output_path=output_path
    )

with open("/home/moha/AIC-4/data_competition/metadata/contestant_manifest.json", "r") as f:
    test_public_lb = json.load(f)["public_lb"]
submission_df = defaultdict(list)
for key, value in test_public_lb.items():
    video_path = os.path.join(data_dir, value["video_path"])
    output_path = os.path.join(outputs_dir, value["video_path"])
    print(video_path, output_path)

    head, tail = os.path.split(output_path)
    bbox_dir = os.path.join(head, 'bboxes')
    bbox_file = os.path.join(bbox_dir, os.path.splitext(tail)[0] + '.txt')

    seq_id = os.path.splitext(value["video_path"])[0]
    if os.path.exists(bbox_file):
        with open(bbox_file, 'r') as f:
            lines = f.read().strip().split('\n')

            for frame_idx, line in enumerate(lines):
                x, y, w, h = line.strip().split()
                submission_df["id"].append(f"{key}_{frame_idx}")
                submission_df["x"].append(float(x))
                submission_df["y"].append(float(y))
                submission_df["w"].append(float(w))
                submission_df["h"].append(float(h))

submission = pd.DataFrame(submission_df)
submission.to_csv("submission.csv", index=False)

print(submission.head())
print(f"Total rows: {len(submission)}")
# Out:
# WARNING:py.warnings:/home/moha/miniconda3/envs/SiamABC_modern/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
#
# WARNING:py.warnings:/home/moha/miniconda3/envs/SiamABC_modern/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
#
# WARNING:torch_tensorrt [TensorRT Conversion Context]:WARNING The logger passed into createInferBuilder differs from one already registered for an existing builder, runtime, or refitter. So the current new logger is ignored, and TensorRT will use the existing one which is returned by nvinfer1::getLogger() instead.
# INFO:torch_tensorrt [TensorRT Conversion Context]:[MemUsageChange] Init builder kernel library: CPU -270, GPU +0, now: CPU 3312, GPU 1913 (MiB)
# INFO:torch_tensorrt [TensorRT Conversion Context]:Global timing cache in use. Profiling results in this builder pass will be stored.
# INFO:torch_tensorrt [TensorRT Conversion Context]:Detected 1 inputs and 1 output network tensors.
# INFO:torch_tensorrt [TensorRT Conversion Context]:Total Host Persistent Memory: 272768 bytes
# INFO:torch_tensorrt [TensorRT Conversion Context]:Total Device Persistent Memory: 0 bytes
# INFO:torch_tensorrt [TensorRT Conversion Context]:Max Scratch Memory: 0 bytes
# INFO:torch_tensorrt [TensorRT Conversion Context]:[BlockAssignment] Started assigning block shifts. This will take 63 steps to complete.
# INFO:torch_tensorrt [TensorRT Conversion Context]:[BlockAssignment] Algorithm ShiftNTopDown took 1.06639ms to assign 5 blocks to 63 nodes requiring 2425344 bytes.
# INFO:torch_tensorrt [TensorRT Conversion Context]:Total Activation Memory: 2424832 bytes
# INFO:torch_tensorrt [TensorRT Conversion Context]:Total Weights Memory: 35184128 bytes
# INFO:torch_tensorrt [TensorRT Conversion Context]:Engine generation completed in 13.8993 seconds.
# INFO:torch_tensorrt [TensorRT Conversion Context]:[MemUsageStats] Peak memory usage of TRT CPU/GPU memory allocators: CPU 4 MiB, GPU 148 MiB
# INFO:torch_tensorrt [TensorRT Conversion Context]:Serialized 27 bytes of code generator cache.
# INFO:torch_tensorrt [TensorRT Conversion Context]:Serialized 3 bytes of compilation cache.
# INFO:torch_tensorrt [TensorRT Conversion Context]:Serialized 239 timing cache entries
# WARNING:torch_tensorrt [TensorRT Conversion Context]:WARNING The logger passed into createInferBuilder differs from one already registered for an existing builder, runtime, or refitter. So the current new logger is ignored, and TensorRT will use the existing one which is returned by nvinfer1::getLogger() instead.
# INFO:torch_tensorrt [TensorRT Conversion Context]:[MemUsageChange] Init builder kernel library: CPU -269, GPU +0, now: CPU 3307, GPU 2129 (MiB)
# INFO:torch_tensorrt [TensorRT Conversion Context]:Global timing cache in use. Profiling results in this builder pass will be stored.
# INFO:torch_tensorrt [TensorRT Conversion Context]:Detected 1 inputs and 1 output network tensors.
# INFO:torch_tensorrt [TensorRT Conversion Context]:Total Host Persistent Memory: 280544 bytes
# INFO:torch_tensorrt [TensorRT Conversion Context]:Total Device Persistent Memory: 8704 bytes
# INFO:torch_tensorrt [TensorRT Conversion Context]:Max Scratch Memory: 4608 bytes
# INFO:torch_tensorrt [TensorRT Conversion Context]:[BlockAssignment] Started assigning block shifts. This will take 69 steps to complete.
# INFO:torch_tensorrt [TensorRT Conversion Context]:[BlockAssignment] Algorithm ShiftNTopDown took 1.66272ms to assign 4 blocks to 69 nodes requiring 9441792 bytes.
# INFO:torch_tensorrt [TensorRT Conversion Context]:Total Activation Memory: 9441792 bytes
# INFO:torch_tensorrt [TensorRT Conversion Context]:Total Weights Memory: 45735424 bytes
# INFO:torch_tensorrt [TensorRT Conversion Context]:Engine generation completed in 13.0441 seconds.
# INFO:torch_tensorrt [TensorRT Conversion Context]:[MemUsageStats] Peak memory usage of TRT CPU/GPU memory allocators: CPU 6 MiB, GPU 193 MiB
# INFO:torch_tensorrt [TensorRT Conversion Context]:Serialized 27 bytes of code generator cache.
# INFO:torch_tensorrt [TensorRT Conversion Context]:Serialized 3 bytes of compilation cache.
# INFO:torch_tensorrt [TensorRT Conversion Context]:Serialized 235 timing cache entries
# INFO:models.SiamABC.tracker.trt_engine.connector:TRTSiamABCNet: building connect_model TRT engine [lam=0.0000] …
# WARNING:torch_tensorrt [TensorRT Conversion Context]:WARNING The logger passed into createInferBuilder differs from one already registered for an existing builder, runtime, or refitter. So the current new logger is ignored, and TensorRT will use the existing one which is returned by nvinfer1::getLogger() instead.
# INFO:torch_tensorrt [TensorRT Conversion Context]:[MemUsageChange] Init builder kernel library: CPU -269, GPU +0, now: CPU 3328, GPU 2203 (MiB)
# INFO:torch_tensorrt [TensorRT Conversion Context]:Global timing cache in use. Profiling results in this builder pass will be stored.
# INFO:torch_tensorrt [TensorRT Conversion Context]:Compiler backend is used during engine build.
# INFO:torch_tensorrt [TensorRT Conversion Context]:[GraphReduction] The approximate region cut reduction algorithm is called.
# INFO:torch_tensorrt [TensorRT Conversion Context]:Detected 3 inputs and 2 output network tensors.
# INFO:torch_tensorrt [TensorRT Conversion Context]:Total Host Persistent Memory: 175920 bytes
# INFO:torch_tensorrt [TensorRT Conversion Context]:Total Device Persistent Memory: 0 bytes
# INFO:torch_tensorrt [TensorRT Conversion Context]:Max Scratch Memory: 655360 bytes
# INFO:torch_tensorrt [TensorRT Conversion Context]:[BlockAssignment] Started assigning block shifts. This will take 135 steps to complete.
# INFO:torch_tensorrt [TensorRT Conversion Context]:[BlockAssignment] Algorithm ShiftNTopDown took 2.94387ms to assign 14 blocks to 135 nodes requiring 2302976 bytes.
# INFO:torch_tensorrt [TensorRT Conversion Context]:Total Activation Memory: 2301440 bytes
# INFO:torch_tensorrt [TensorRT Conversion Context]:Total Weights Memory: 4525072 bytes
# INFO:torch_tensorrt [TensorRT Conversion Context]:Compiler backend is used during engine execution.
# INFO:torch_tensorrt [TensorRT Conversion Context]:Engine generation completed in 14.6951 seconds.
# INFO:torch_tensorrt [TensorRT Conversion Context]:[MemUsageStats] Peak memory usage of TRT CPU/GPU memory allocators: CPU 6 MiB, GPU 216 MiB
# INFO:torch_tensorrt [TensorRT Conversion Context]:Serialized 146 bytes of code generator cache.
# INFO:torch_tensorrt [TensorRT Conversion Context]:Serialized 48821 bytes of compilation cache.
# INFO:torch_tensorrt [TensorRT Conversion Context]:Serialized 308 timing cache entries
# WARNING: [Torch-TensorRT] - Using default stream in enqueueV3() may lead to performance issues due to additional calls to cudaStreamSynchronize() by TensorRT to ensure correct synchronization. Please use non-default stream instead.
# INFO:models.SiamABC.tracker.trt_engine.connector:TRTSiamABCNet: connect_model engine [lam=0.0000] ready.
# INFO:models.SiamABC.tracker.trt_engine.connector:TRTSiamABCNet: building connect_model TRT engine [lam=0.1000] …
# WARNING:torch_tensorrt [TensorRT Conversion Context]:WARNING The logger passed into createInferBuilder differs from one already registered for an existing builder, runtime, or refitter. So the current new logger is ignored, and TensorRT will use the existing one which is returned by nvinfer1::getLogger() instead.
# INFO:torch_tensorrt [TensorRT Conversion Context]:[MemUsageChange] Init builder kernel library: CPU -269, GPU +0, now: CPU 4012, GPU 2211 (MiB)
# INFO:torch_tensorrt [TensorRT Conversion Context]:Global timing cache in use. Profiling results in this builder pass will be stored.
# INFO:torch_tensorrt [TensorRT Conversion Context]:Compiler backend is used during engine build.
# INFO:torch_tensorrt [TensorRT Conversion Context]:[GraphReduction] The approximate region cut reduction algorithm is called.
# INFO:torch_tensorrt [TensorRT Conversion Context]:Detected 3 inputs and 2 output network tensors.
# INFO:torch_tensorrt [TensorRT Conversion Context]:Total Host Persistent Memory: 175920 bytes
# INFO:torch_tensorrt [TensorRT Conversion Context]:Total Device Persistent Memory: 0 bytes
# INFO:torch_tensorrt [TensorRT Conversion Context]:Max Scratch Memory: 655360 bytes
# INFO:torch_tensorrt [TensorRT Conversion Context]:[BlockAssignment] Started assigning block shifts. This will take 135 steps to complete.
# INFO:torch_tensorrt [TensorRT Conversion Context]:[BlockAssignment] Algorithm ShiftNTopDown took 4.75405ms to assign 14 blocks to 135 nodes requiring 2302976 bytes.
# INFO:torch_tensorrt [TensorRT Conversion Context]:Total Activation Memory: 2301440 bytes
# INFO:torch_tensorrt [TensorRT Conversion Context]:Total Weights Memory: 4525072 bytes
# INFO:torch_tensorrt [TensorRT Conversion Context]:Compiler backend is used during engine execution.
# INFO:torch_tensorrt [TensorRT Conversion Context]:Engine generation completed in 13.6832 seconds.
# INFO:torch_tensorrt [TensorRT Conversion Context]:[MemUsageStats] Peak memory usage of TRT CPU/GPU memory allocators: CPU 6 MiB, GPU 222 MiB
# INFO:torch_tensorrt [TensorRT Conversion Context]:Serialized 203 bytes of code generator cache.
# INFO:torch_tensorrt [TensorRT Conversion Context]:Serialized 48821 bytes of compilation cache.
# INFO:torch_tensorrt [TensorRT Conversion Context]:Serialized 309 timing cache entries
# WARNING: [Torch-TensorRT] - Using default stream in enqueueV3() may lead to performance issues due to additional calls to cudaStreamSynchronize() by TensorRT to ensure correct synchronization. Please use non-default stream instead.
# INFO:models.SiamABC.tracker.trt_engine.connector:TRTSiamABCNet: connect_model engine [lam=0.1000] ready.
# WARNING: [Torch-TensorRT] - Using default stream in enqueueV3() may lead to performance issues due to additional calls to cudaStreamSynchronize() by TensorRT to ensure correct synchronization. Please use non-default stream instead.
# WARNING: [Torch-TensorRT] - Using default stream in enqueueV3() may lead to performance issues due to additional calls to cudaStreamSynchronize() by TensorRT to ensure correct synchronization. Please use non-default stream instead.
# {'penalty_k': 0.062, 'window_influence': 0.38, 'lr': 0.4, 'windowing': 'cosine', 'total_stride': 16, 'score_size': 16, 'N': 10, 'dynamic_update': True, 'similarity_score': False, 'stride': 2, 'smooth': False, 'bbox_ratio': 0.5, 'template_bbox_offset': 0.2, 'search_context': 2, 'instance_size': 256, 'template_size': 128, 'memory_window_size': 20, 'dynamic_update_threshold': 0.87, 'running_confidence_floor_value': 100, 'iou_threshold': 0.6, 'warmup_frames': 35, 'warmup_window_size': 8}
# Processing video 1/89: dataset1/Car_video/Car_video.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 584  mean=11.8ms  med=10.4ms  p95=18.3ms  p99=23.9ms  min=7.7ms  max=29.3ms  fps=84.4
# NORMAL TRACK          n= 584  mean=11.8ms  med=10.4ms  p95=18.3ms  p99=23.9ms  min=7.7ms  max=29.3ms  fps=84.4
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 2/89: dataset1/Car_video_4/Car_video_4.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 414  mean=10.0ms  med=9.3ms  p95=15.8ms  p99=21.1ms  min=6.5ms  max=25.1ms  fps=99.6
# NORMAL TRACK          n= 414  mean=10.0ms  med=9.3ms  p95=15.8ms  p99=21.1ms  min=6.5ms  max=25.1ms  fps=99.6
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 3/89: dataset1/basketball/basketball.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 323  mean=12.6ms  med=10.4ms  p95=19.5ms  p99=25.4ms  min=7.9ms  max=232.4ms  fps=79.6
# NORMAL TRACK          n= 321  mean=11.9ms  med=10.4ms  p95=19.3ms  p99=25.2ms  min=7.9ms  max=28.8ms  fps=84.3
# OCCLUSION             n=   2  mean=126.8ms  med=126.8ms  p95=221.9ms  p99=230.3ms  min=21.1ms  max=232.4ms  fps=7.9
#   occlusion frames: 2 (0.6% of total)
# ──────────────────────────────────────────────────────────
#
# Processing video 4/89: dataset1/basketball_2/basketball_2.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 183  mean=11.8ms  med=10.3ms  p95=16.7ms  p99=23.9ms  min=2.3ms  max=140.6ms  fps=84.4
# NORMAL TRACK          n= 162  mean=11.2ms  med=10.3ms  p95=16.5ms  p99=21.7ms  min=7.9ms  max=23.2ms  fps=89.2
# OCCLUSION             n=  21  mean=16.7ms  med=11.1ms  p95=26.8ms  p99=117.9ms  min=2.3ms  max=140.6ms  fps=59.8
#   occlusion frames: 21 (11.5% of total)
# ──────────────────────────────────────────────────────────
#
# Processing video 5/89: dataset1/basketball_3/basketball_3.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 180  mean=11.5ms  med=11.0ms  p95=19.2ms  p99=25.7ms  min=2.3ms  max=28.7ms  fps=87.2
# NORMAL TRACK          n= 124  mean=12.1ms  med=10.7ms  p95=21.2ms  p99=27.5ms  min=8.0ms  max=28.7ms  fps=82.7
# OCCLUSION             n=  56  mean=10.1ms  med=11.5ms  p95=17.3ms  p99=22.1ms  min=2.3ms  max=24.9ms  fps=99.0
#   occlusion frames: 56 (31.1% of total)
# ──────────────────────────────────────────────────────────
#
# Processing video 6/89: dataset1/cows/cows.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 488  mean=14.1ms  med=13.4ms  p95=21.8ms  p99=28.1ms  min=8.9ms  max=35.1ms  fps=70.9
# NORMAL TRACK          n= 488  mean=14.1ms  med=13.4ms  p95=21.8ms  p99=28.1ms  min=8.9ms  max=35.1ms  fps=70.9
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 7/89: dataset1/person_3/person_3.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 929  mean=10.0ms  med=10.1ms  p95=16.8ms  p99=22.5ms  min=1.1ms  max=125.7ms  fps=99.6
# NORMAL TRACK          n= 574  mean=10.6ms  med=10.3ms  p95=16.7ms  p99=20.5ms  min=6.3ms  max=32.0ms  fps=94.1
# OCCLUSION             n= 355  mean=9.1ms  med=9.5ms  p95=16.8ms  p99=24.9ms  min=1.1ms  max=125.7ms  fps=110.0
#   occlusion frames: 355 (38.2% of total)
# ──────────────────────────────────────────────────────────
#
# Processing video 8/89: dataset1/sheeps/sheeps.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 282  mean=14.0ms  med=13.0ms  p95=22.9ms  p99=35.8ms  min=8.4ms  max=42.0ms  fps=71.6
# NORMAL TRACK          n= 268  mean=13.6ms  med=12.9ms  p95=21.7ms  p99=29.0ms  min=8.4ms  max=42.0ms  fps=73.3
# OCCLUSION             n=  14  mean=20.1ms  med=15.2ms  p95=39.2ms  p99=39.5ms  min=9.2ms  max=39.6ms  fps=49.7
#   occlusion frames: 14 (5.0% of total)
# ──────────────────────────────────────────────────────────
#
# Processing video 9/89: dataset1/sheeps_2/sheeps_2.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 239  mean=13.4ms  med=12.8ms  p95=21.4ms  p99=27.5ms  min=8.4ms  max=31.3ms  fps=74.9
# NORMAL TRACK          n= 239  mean=13.4ms  med=12.8ms  p95=21.4ms  p99=27.5ms  min=8.4ms  max=31.3ms  fps=74.9
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 10/89: dataset1/surfer_1/surfer_1.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 742  mean=10.0ms  med=9.3ms  p95=16.2ms  p99=24.2ms  min=1.2ms  max=32.5ms  fps=99.6
# NORMAL TRACK          n= 609  mean=10.3ms  med=9.3ms  p95=15.9ms  p99=23.6ms  min=6.2ms  max=32.2ms  fps=97.3
# OCCLUSION             n= 133  mean=8.9ms  med=8.9ms  p95=18.2ms  p99=27.8ms  min=1.2ms  max=32.5ms  fps=112.1
#   occlusion frames: 133 (17.9% of total)
# ──────────────────────────────────────────────────────────
#
# Processing video 11/89: dataset2/Animal3/Animal3_30.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 308  mean=10.2ms  med=8.9ms  p95=16.6ms  p99=21.4ms  min=6.8ms  max=28.3ms  fps=98.2
# NORMAL TRACK          n= 308  mean=10.2ms  med=8.9ms  p95=16.6ms  p99=21.4ms  min=6.8ms  max=28.3ms  fps=98.2
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 12/89: dataset2/Car4/Car4_24.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 216  mean=9.9ms  med=8.5ms  p95=17.2ms  p99=22.4ms  min=6.6ms  max=23.2ms  fps=100.6
# NORMAL TRACK          n= 216  mean=9.9ms  med=8.5ms  p95=17.2ms  p99=22.4ms  min=6.6ms  max=23.2ms  fps=100.6
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 13/89: dataset2/Car5/Car5_30.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n=  83  mean=9.6ms  med=8.1ms  p95=16.0ms  p99=19.0ms  min=6.9ms  max=21.7ms  fps=103.7
# NORMAL TRACK          n=  83  mean=9.6ms  med=8.1ms  p95=16.0ms  p99=19.0ms  min=6.9ms  max=21.7ms  fps=103.7
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 14/89: dataset2/Horse1/Horse1_24.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 148  mean=10.5ms  med=9.3ms  p95=17.6ms  p99=19.9ms  min=6.9ms  max=23.5ms  fps=95.6
# NORMAL TRACK          n= 148  mean=10.5ms  med=9.3ms  p95=17.6ms  p99=19.9ms  min=6.9ms  max=23.5ms  fps=95.6
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 15/89: dataset2/Motor1/Motor1_24.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n=  77  mean=10.6ms  med=9.0ms  p95=18.2ms  p99=20.5ms  min=2.1ms  max=20.6ms  fps=94.5
# NORMAL TRACK          n=  71  mean=10.5ms  med=9.0ms  p95=17.5ms  p99=20.5ms  min=7.2ms  max=20.6ms  fps=95.1
# OCCLUSION             n=   6  mean=11.3ms  med=12.9ms  p95=17.3ms  p99=17.9ms  min=2.1ms  max=18.1ms  fps=88.2
#   occlusion frames: 6 (7.8% of total)
# ──────────────────────────────────────────────────────────
#
# Processing video 16/89: dataset2/MountainBike5/MountainBike5_30.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 106  mean=10.6ms  med=8.7ms  p95=18.2ms  p99=25.2ms  min=6.5ms  max=29.6ms  fps=94.6
# NORMAL TRACK          n= 106  mean=10.6ms  med=8.7ms  p95=18.2ms  p99=25.2ms  min=6.5ms  max=29.6ms  fps=94.6
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 17/89: dataset2/RaceCar1/RaceCar1_24.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 248  mean=10.0ms  med=9.1ms  p95=16.0ms  p99=20.8ms  min=1.5ms  max=26.0ms  fps=100.3
# NORMAL TRACK          n= 202  mean=10.1ms  med=8.9ms  p95=15.3ms  p99=19.3ms  min=7.0ms  max=26.0ms  fps=99.4
# OCCLUSION             n=  46  mean=9.6ms  med=10.7ms  p95=19.5ms  p99=20.8ms  min=1.5ms  max=20.9ms  fps=104.4
#   occlusion frames: 46 (18.5% of total)
# ──────────────────────────────────────────────────────────
#
# Processing video 18/89: dataset2/RcCar4/RcCar4_24.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 698  mean=10.2ms  med=9.1ms  p95=17.6ms  p99=25.1ms  min=1.5ms  max=30.1ms  fps=97.8
# NORMAL TRACK          n= 663  mean=10.3ms  med=9.1ms  p95=17.6ms  p99=24.5ms  min=6.7ms  max=30.1ms  fps=97.5
# OCCLUSION             n=  35  mean=9.6ms  med=9.2ms  p95=19.1ms  p99=26.6ms  min=1.5ms  max=28.7ms  fps=104.6
#   occlusion frames: 35 (5.0% of total)
# ──────────────────────────────────────────────────────────
#
# Processing video 19/89: dataset2/RcCar6/RcCar6_24.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 209  mean=11.2ms  med=9.3ms  p95=19.5ms  p99=25.4ms  min=1.6ms  max=125.9ms  fps=89.0
# NORMAL TRACK          n= 191  mean=10.8ms  med=9.3ms  p95=18.8ms  p99=24.0ms  min=6.6ms  max=25.5ms  fps=92.8
# OCCLUSION             n=  18  mean=16.1ms  med=10.1ms  p95=47.0ms  p99=110.1ms  min=1.6ms  max=125.9ms  fps=62.2
#   occlusion frames: 18 (8.6% of total)
# ──────────────────────────────────────────────────────────
#
# Processing video 20/89: dataset2/RcCar9/RcCar9_24.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 207  mean=10.9ms  med=9.5ms  p95=18.3ms  p99=27.2ms  min=7.0ms  max=31.4ms  fps=91.4
# NORMAL TRACK          n= 207  mean=10.9ms  med=9.5ms  p95=18.3ms  p99=27.2ms  min=7.0ms  max=31.4ms  fps=91.4
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 21/89: dataset2/SUP4/SUP4_24.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 294  mean=10.6ms  med=9.3ms  p95=17.5ms  p99=23.2ms  min=6.8ms  max=28.1ms  fps=94.7
# NORMAL TRACK          n= 294  mean=10.6ms  med=9.3ms  p95=17.5ms  p99=23.2ms  min=6.8ms  max=28.1ms  fps=94.7
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 22/89: dataset2/SnowBoarding2/SnowBoarding2_24.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 116  mean=9.9ms  med=8.8ms  p95=15.2ms  p99=17.8ms  min=6.9ms  max=19.0ms  fps=101.1
# NORMAL TRACK          n= 116  mean=9.9ms  med=8.8ms  p95=15.2ms  p99=17.8ms  min=6.9ms  max=19.0ms  fps=101.1
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 23/89: dataset2/Soccer1/Soccer1_24.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 612  mean=10.5ms  med=8.8ms  p95=17.8ms  p99=23.9ms  min=6.8ms  max=30.1ms  fps=95.5
# NORMAL TRACK          n= 612  mean=10.5ms  med=8.8ms  p95=17.8ms  p99=23.9ms  min=6.8ms  max=30.1ms  fps=95.5
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 24/89: dataset2/SpeedCar2/SpeedCar2_30.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 307  mean=10.6ms  med=8.9ms  p95=18.3ms  p99=22.2ms  min=6.7ms  max=37.4ms  fps=94.8
# NORMAL TRACK          n= 307  mean=10.6ms  med=8.9ms  p95=18.3ms  p99=22.2ms  min=6.7ms  max=37.4ms  fps=94.8
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 25/89: dataset2/Surfing03/Surfing03_24.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 116  mean=9.6ms  med=8.2ms  p95=14.5ms  p99=19.1ms  min=7.0ms  max=23.6ms  fps=103.7
# NORMAL TRACK          n= 116  mean=9.6ms  med=8.2ms  p95=14.5ms  p99=19.1ms  min=7.0ms  max=23.6ms  fps=103.7
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 26/89: dataset2/Surfing06/Surfing06_24.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 105  mean=10.2ms  med=9.4ms  p95=15.1ms  p99=18.2ms  min=6.9ms  max=20.8ms  fps=97.6
# NORMAL TRACK          n= 105  mean=10.2ms  med=9.4ms  p95=15.1ms  p99=18.2ms  min=6.9ms  max=20.8ms  fps=97.6
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 27/89: dataset2/Wakeboarding1/Wakeboarding1_24.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n=  76  mean=10.3ms  med=8.6ms  p95=17.4ms  p99=24.9ms  min=6.8ms  max=29.2ms  fps=97.3
# NORMAL TRACK          n=  76  mean=10.3ms  med=8.6ms  p95=17.4ms  p99=24.9ms  min=6.8ms  max=29.2ms  fps=97.3
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 28/89: dataset3/air_conditioning_box1/air_conditioning_box1_30.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 436  mean=10.1ms  med=8.6ms  p95=17.4ms  p99=23.0ms  min=6.6ms  max=29.9ms  fps=98.7
# NORMAL TRACK          n= 436  mean=10.1ms  med=8.6ms  p95=17.4ms  p99=23.0ms  min=6.6ms  max=29.9ms  fps=98.7
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 29/89: dataset3/bike1/bike1_30.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 179  mean=12.7ms  med=12.1ms  p95=20.1ms  p99=25.0ms  min=8.0ms  max=32.7ms  fps=78.7
# NORMAL TRACK          n= 179  mean=12.7ms  med=12.1ms  p95=20.1ms  p99=25.0ms  min=8.0ms  max=32.7ms  fps=78.7
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 30/89: dataset3/bike7_1/bike7_1_30.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 300  mean=13.0ms  med=12.4ms  p95=20.4ms  p99=27.6ms  min=8.0ms  max=32.1ms  fps=77.0
# NORMAL TRACK          n= 300  mean=13.0ms  med=12.4ms  p95=20.4ms  p99=27.6ms  min=8.0ms  max=32.1ms  fps=77.0
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 31/89: dataset3/bike7_2/bike7_2_30.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 337  mean=13.1ms  med=12.1ms  p95=21.2ms  p99=26.8ms  min=8.1ms  max=32.5ms  fps=76.4
# NORMAL TRACK          n= 337  mean=13.1ms  med=12.1ms  p95=21.2ms  p99=26.8ms  min=8.1ms  max=32.5ms  fps=76.4
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 32/89: dataset3/bike9_1/bike9_1_30.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 400  mean=13.8ms  med=13.6ms  p95=20.4ms  p99=29.6ms  min=8.4ms  max=38.1ms  fps=72.5
# NORMAL TRACK          n= 400  mean=13.8ms  med=13.6ms  p95=20.4ms  p99=29.6ms  min=8.4ms  max=38.1ms  fps=72.5
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 33/89: dataset3/bus1-n/bus1-n_30.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n=1091  mean=10.0ms  med=9.0ms  p95=15.9ms  p99=20.5ms  min=6.4ms  max=30.0ms  fps=99.7
# NORMAL TRACK          n=1091  mean=10.0ms  med=9.0ms  p95=15.9ms  p99=20.5ms  min=6.4ms  max=30.0ms  fps=99.7
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 34/89: dataset3/car16_3/car16_3_24.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 167  mean=12.3ms  med=11.8ms  p95=18.9ms  p99=25.0ms  min=7.9ms  max=28.6ms  fps=81.0
# NORMAL TRACK          n= 167  mean=12.3ms  med=11.8ms  p95=18.9ms  p99=25.0ms  min=7.9ms  max=28.6ms  fps=81.0
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 35/89: dataset3/car4/car4_30.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n=1301  mean=10.0ms  med=8.7ms  p95=17.4ms  p99=23.0ms  min=1.5ms  max=38.1ms  fps=100.4
# NORMAL TRACK          n=1038  mean=10.2ms  med=8.6ms  p95=17.4ms  p99=23.0ms  min=6.8ms  max=38.1ms  fps=97.9
# OCCLUSION             n= 263  mean=9.0ms  med=9.9ms  p95=17.0ms  p99=20.7ms  min=1.5ms  max=31.0ms  fps=111.5
#   occlusion frames: 263 (20.2% of total)
# ──────────────────────────────────────────────────────────
#
# Processing video 36/89: dataset3/car6_2/car6_2_30.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n=1122  mean=9.9ms  med=8.5ms  p95=16.0ms  p99=20.6ms  min=1.5ms  max=28.3ms  fps=101.5
# NORMAL TRACK          n=1110  mean=9.9ms  med=8.5ms  p95=16.0ms  p99=20.3ms  min=6.4ms  max=28.3ms  fps=101.4
# OCCLUSION             n=  12  mean=9.0ms  med=8.3ms  p95=18.6ms  p99=23.5ms  min=1.5ms  max=24.7ms  fps=111.3
#   occlusion frames: 12 (1.1% of total)
# ──────────────────────────────────────────────────────────
#
# Processing video 37/89: dataset3/car7_1/car7_1_30.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 972  mean=11.0ms  med=9.9ms  p95=18.1ms  p99=22.7ms  min=6.7ms  max=32.0ms  fps=91.2
# NORMAL TRACK          n= 972  mean=11.0ms  med=9.9ms  p95=18.1ms  p99=22.7ms  min=6.7ms  max=32.0ms  fps=91.2
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 38/89: dataset3/car7_2/car7_2_24.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n=1967  mean=10.1ms  med=10.0ms  p95=14.5ms  p99=18.9ms  min=6.4ms  max=33.8ms  fps=99.1
# NORMAL TRACK          n=1967  mean=10.1ms  med=10.0ms  p95=14.5ms  p99=18.9ms  min=6.4ms  max=33.8ms  fps=99.1
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 39/89: dataset3/couple/couple_24.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n=1825  mean=8.2ms  med=7.5ms  p95=12.1ms  p99=15.6ms  min=1.3ms  max=21.1ms  fps=122.1
# NORMAL TRACK          n=1791  mean=8.2ms  med=7.5ms  p95=12.1ms  p99=15.3ms  min=5.8ms  max=19.0ms  fps=121.9
# OCCLUSION             n=  34  mean=7.7ms  med=6.8ms  p95=19.7ms  p99=20.9ms  min=1.3ms  max=21.1ms  fps=129.9
#   occlusion frames: 34 (1.9% of total)
# ──────────────────────────────────────────────────────────
#
# Processing video 40/89: dataset3/courier2/courier2_30.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n=1704  mean=9.3ms  med=8.1ms  p95=14.3ms  p99=18.1ms  min=6.1ms  max=20.8ms  fps=107.5
# NORMAL TRACK          n=1704  mean=9.3ms  med=8.1ms  p95=14.3ms  p99=18.1ms  min=6.1ms  max=20.8ms  fps=107.5
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 41/89: dataset3/duck2/duck2_24.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n=1130  mean=8.7ms  med=7.4ms  p95=13.4ms  p99=17.0ms  min=6.0ms  max=21.1ms  fps=115.1
# NORMAL TRACK          n=1130  mean=8.7ms  med=7.4ms  p95=13.4ms  p99=17.0ms  min=6.0ms  max=21.1ms  fps=115.1
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 42/89: dataset3/electric_box/electric_box_24.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n=1163  mean=10.3ms  med=10.2ms  p95=17.9ms  p99=24.9ms  min=1.2ms  max=36.7ms  fps=97.5
# NORMAL TRACK          n= 825  mean=10.0ms  med=9.9ms  p95=13.8ms  p99=17.6ms  min=6.1ms  max=19.3ms  fps=100.0
# OCCLUSION             n= 338  mean=10.9ms  med=10.7ms  p95=24.7ms  p99=26.6ms  min=1.2ms  max=36.7ms  fps=91.7
#   occlusion frames: 338 (29.1% of total)
# ──────────────────────────────────────────────────────────
#
# Processing video 43/89: dataset3/excavator/excavator_30.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 629  mean=9.6ms  med=9.3ms  p95=14.1ms  p99=17.1ms  min=6.1ms  max=20.8ms  fps=104.4
# NORMAL TRACK          n= 629  mean=9.6ms  med=9.3ms  p95=14.1ms  p99=17.1ms  min=6.1ms  max=20.8ms  fps=104.4
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 44/89: dataset3/football_player1_3/football_player1_3_24.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n=1002  mean=8.3ms  med=7.6ms  p95=12.4ms  p99=14.8ms  min=6.1ms  max=18.1ms  fps=120.6
# NORMAL TRACK          n=1002  mean=8.3ms  med=7.6ms  p95=12.4ms  p99=14.8ms  min=6.1ms  max=18.1ms  fps=120.6
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 45/89: dataset3/group3_1/group3_1_24.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 162  mean=15.2ms  med=14.8ms  p95=17.7ms  p99=21.7ms  min=12.8ms  max=22.1ms  fps=65.9
# NORMAL TRACK          n= 162  mean=15.2ms  med=14.8ms  p95=17.7ms  p99=21.7ms  min=12.8ms  max=22.1ms  fps=65.9
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 46/89: dataset3/group3_2/group3_2_24.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 249  mean=14.7ms  med=14.3ms  p95=18.1ms  p99=20.2ms  min=12.6ms  max=24.3ms  fps=67.8
# NORMAL TRACK          n= 249  mean=14.7ms  med=14.3ms  p95=18.1ms  p99=20.2ms  min=12.6ms  max=24.3ms  fps=67.8
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 47/89: dataset3/human/human_24.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n=1604  mean=8.4ms  med=7.7ms  p95=12.0ms  p99=14.0ms  min=6.1ms  max=18.1ms  fps=118.9
# NORMAL TRACK          n=1604  mean=8.4ms  med=7.7ms  p95=12.0ms  p99=14.0ms  min=6.1ms  max=18.1ms  fps=118.9
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 48/89: dataset3/human1/human1_24.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n=  89  mean=12.4ms  med=12.6ms  p95=16.1ms  p99=16.8ms  min=9.2ms  max=17.0ms  fps=80.8
# NORMAL TRACK          n=  89  mean=12.4ms  med=12.6ms  p95=16.1ms  p99=16.8ms  min=9.2ms  max=17.0ms  fps=80.8
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 49/89: dataset3/human4/human4_24.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n=  19  mean=14.0ms  med=13.8ms  p95=16.3ms  p99=18.5ms  min=12.1ms  max=19.0ms  fps=71.5
# NORMAL TRACK          n=  19  mean=14.0ms  med=13.8ms  p95=16.3ms  p99=18.5ms  min=12.1ms  max=19.0ms  fps=71.5
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 50/89: dataset3/human5/human5_24.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n= 207  mean=14.2ms  med=13.7ms  p95=18.8ms  p99=31.6ms  min=2.7ms  max=37.4ms  fps=70.2
# NORMAL TRACK          n= 174  mean=14.4ms  med=13.8ms  p95=18.3ms  p99=21.9ms  min=12.0ms  max=23.8ms  fps=69.3
# OCCLUSION             n=  33  mean=13.3ms  med=13.0ms  p95=33.1ms  p99=36.5ms  min=2.7ms  max=37.4ms  fps=75.3
#   occlusion frames: 33 (15.9% of total)
# ──────────────────────────────────────────────────────────
#
# Processing video 51/89: dataset3/jogging2/jogging2_30.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n=1716  mean=8.6ms  med=7.7ms  p95=13.0ms  p99=15.7ms  min=1.4ms  max=22.5ms  fps=116.8
# NORMAL TRACK          n=1634  mean=8.6ms  med=7.7ms  p95=13.0ms  p99=15.4ms  min=6.2ms  max=22.3ms  fps=115.9
# OCCLUSION             n=  82  mean=7.3ms  med=7.6ms  p95=12.3ms  p99=19.0ms  min=1.4ms  max=22.5ms  fps=137.7
#   occlusion frames: 82 (4.8% of total)
# ──────────────────────────────────────────────────────────
#
# Processing video 52/89: dataset3/motor2/motor2_24.mp4
#
# ─── Latency Report ───────────────────────────────────────
# ALL FRAMES            n=  52  mean=9.6ms  med=9.1ms  p95=13.7ms  p99=15.7ms  min=7.9ms  max=17.2ms  fps=104.0
# NORMAL TRACK          n=  52  mean=9.6ms  med=9.1ms  p95=13.7ms  p99=15.7ms  min=7.9ms  max=17.2ms  fps=104.0
# OCCLUSION             no data
# ──────────────────────────────────────────────────────────
#
# Processing video 53/89: dataset3/parterre2/parterre2_30.mp4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 183
#     177     output_path = os.path.join(
#     178         outputs_dir, value["video_path"]
#     179     )
#     181     init_bbox = np.loadtxt(ann_path, delimiter=",", dtype=np.float32).tolist()
# --> 183     run_inference(
#     184         video_path=video_path,
#     185         initial_bbox=init_bbox,
#     186         tracker=tracker,
#     187         output_path=output_path
#     188     )
#     190 with open("/home/moha/AIC-4/data_competition/metadata/contestant_manifest.json", "r") as f:
#     191     test_public_lb = json.load(f)["public_lb"]
#
# File ~/AIC-for submission/SiamRAM/vis/test_model.py:342, in run_inference(initial_bbox, video_path, tracker, output_path, output_video)
#     339     break
#     341 t0 = time.perf_counter()
# --> 342 result = tracker.update(frame)
#     343 elapsed_ms = (time.perf_counter() - t0) * 1000.0
#     344 frame_times.append(elapsed_ms)
#
# File ~/AIC-for submission/SiamRAM/models/SiamRAM.py:468, in SiamRAMTracker.update(self, frame)
#     466     bbox, score = self._occlusion_update(proc_frame)
#     467 else:
# --> 468     bbox, score = self._normal_update(proc_frame)
#     470 self.prev_gray = current_gray
#     472 # ── Scale outputs back to full-frame coordinates ─────────────────────────
#
# File ~/AIC-for submission/SiamRAM/models/SiamRAM.py:520, in SiamRAMTracker._normal_update(self, frame)
#     490 def _normal_update(self, frame: np.ndarray) -> Tuple[np.ndarray, float]:
#     491     """
#     492     Inputs:
#     493         frame - current video frame as a numpy BGR array
#    (...)
#     518         correct EKF state. If this bookkeeping is wrong, recovery will fail.
#     519     """
# --> 520     pred_bbox, score, _ = self.tracker.update(frame)
#     521     pred_bbox = np.array(pred_bbox, dtype=int)
#     523     if (self._yolo_filter_class
#     524         and not self._class_warmup_done
#     525         and self.frame_idx <= self._yolo_class_detect_frames * 3
#     526         and self.frame_idx % max(1, self._yolo_class_detect_frames) == 0):
#
# File ~/AIC-for submission/SiamRAM/models/SiamABC/tracker/SiamABC_Tracker.py:248, in SiamABCTracker.update(self, search, *kw)
#     247 def update(self, search: NDArray, *kw):
# --> 248     pred_bbox, pred_score, sim_score, search_crop_raw, search_bbox_in_crop = self.run_track(search)
#     250     self.tracking_state.bbox = pred_bbox
#     251     self.tracking_state.pred_score = pred_score
#
# File ~/AIC-for submission/SiamRAM/models/SiamABC/tracker/SiamABC_Tracker.py:304, in SiamABCTracker.run_track(self, search)
#     302 self.tracking_state.mapping = search_context
#     303 self.tracking_state.prev_size = search_bbox_in_crop[2:]
# --> 304 pred_bbox, pred_score, sim_score, _ = self.track(
#     305     search_features, self.dynamic_search_features, self.dynamic_template_features
#     306 )
#     307 pred_bbox = self._rescale_bbox(pred_bbox, self.tracking_state.mapping)
#     308 pred_bbox = clamp_bbox(pred_bbox, search.shape)
#
# File ~/miniconda3/envs/SiamABC_modern/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/AIC-for submission/SiamRAM/models/SiamABC/tracker/SiamABC_Tracker.py:313, in SiamABCTracker.track(self, search_features, dynamic_search_features, dynamic_template_features)
#     311 @torch.no_grad()
#     312 def track(self, search_features, dynamic_search_features, dynamic_template_features):
# --> 313     track_result = self.net.track(
#     314         search_features=search_features,
#     315         dynamic_search_features=dynamic_search_features,
#     316         template_features=self._template_features,
#     317         dynamic_template_features=dynamic_template_features,
#     318         lam=self._tta_lam,
#     319     )
#     320     return self._postprocess(track_result=track_result)
#
# File ~/AIC-for submission/SiamRAM/models/SiamABC/tracker/trt_engine/siamabc.py:325, in TRTSiamABCNet.track(self, search_features, dynamic_search_features, template_features, dynamic_template_features, lam)
#     311 s_mixed = self._trt_attn(s_combined).contiguous()   # (B, C, h_s, w_s)
#     314 # All inputs to the FP32 connect_model must be FP32
#     315 # bbox_pred, cls_pred = self._connect_model(
#     316 #     search_org=sf.float().contiguous(),
#    (...)
#     319 #     lam=float(lam.item()),
#     320 # )
#     323 bbox_pred, cls_pred = _dispatch_connect(
#     324     self._connect_engines,
# --> 325     lam_val=float(lam.item()),
#     326     norm_lambda=self._norm_lambda,
#     327     search_org=sf.float().contiguous(),
#     328     search=s_mixed.float(),
#     329     kernel=t_mixed.float(),
#     330 )
#     332 return {
#     333     constants.TARGET_REGRESSION_LABEL_KEY:     bbox_pred.float(),
#     334     constants.TARGET_CLASSIFICATION_KEY:       cls_pred.float(),
#     335     constants.TRACKER_TARGET_SEARCH_SIM_SCORE: None,
#     336     constants.TRACKER_ATTENTION_MAP:           s_mixed.float(),
#     337 }
#
# KeyboardInterrupt:

# %%
submission.to_csv("submission.csv", index=False)

print(submission.head())
print(f"Total rows: {len(submission)}")
# Out:
#                      id      x      y      w      h
# 0  dataset1/Car_video_0  536.0  551.0  226.0  142.0
# 1  dataset1/Car_video_1  533.0  549.0  237.0  150.0
# 2  dataset1/Car_video_2  531.0  549.0  237.0  152.0
# 3  dataset1/Car_video_3  531.0  549.0  237.0  152.0
# 4  dataset1/Car_video_4  529.0  550.0  239.0  155.0
# Total rows: 74293
